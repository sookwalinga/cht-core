# %%
import functions as fn
import pandas as pd, numpy as np 
import itertools, json 


config={}
x=pd.read_excel('mappings.xlsx','variables')
config['missing_columns']=x[x.jna.str.strip()=='_'].us.replace(regex='=',value='_').values
config['us']=x.us
config['nlab_data']=fn.get_nlab_preprocessed_data()
config['jna_data']=fn.transform_jna_data()


def run(title,func,n=1):
  for x in range(n):
      df=func(config)
      df=fn.run_sample(df)
      cm=fn.confusion_matrix(y_true=df['child_death'],y_pred=df['js_result'])
      fn.plot_confusion_matrix(df,title=f'{title}{x+1}')
      # print(cm)
      print('\n\n',title.upper(),'---------')
      print(fn.get_report_summary(df))
      # print(json.dumps(fn.confunsion_accuracy(cm,title=title)),",")

f=['mean','median','rand']
p=['all','shehia','district'] 


for x in itertools.product(p,f):
  func = getattr(fn,'fill_missing_'+'_'.join(x))
  title=x[0]+' '+x[1]
  run(title,func,30 if x[1]=='rand' else 1)
# Out:
#  ALL MEAN ---------
#               precision    recall  f1-score   support
#
#        False       0.95      0.85      0.89      1120
#         True       0.09      0.24      0.13        70
#
#     accuracy                           0.81      1190
#    macro avg       0.52      0.54      0.51      1190
# weighted avg       0.90      0.81      0.85      1190
#
#
#
#  ALL MEDIAN ---------
#               precision    recall  f1-score   support
#
#        False       0.95      0.82      0.88      1120
#         True       0.08      0.26      0.12        70
#
#     accuracy                           0.79      1190
#    macro avg       0.51      0.54      0.50      1190
# weighted avg       0.90      0.79      0.83      1190
#
#
#
#  ALL RAND ---------
#               precision    recall  f1-score   support
#
#        False       0.94      0.65      0.77      1120
#         True       0.06      0.36      0.10        70
#
#     accuracy                           0.63      1190
#    macro avg       0.50      0.50      0.44      1190
# weighted avg       0.89      0.63      0.73      1190
#
#
#
#  ALL RAND ---------
#               precision    recall  f1-score   support
#
#        False       0.95      0.71      0.81      1120
#         True       0.09      0.46      0.15        70
#
#     accuracy                           0.69      1190
#    macro avg       0.52      0.58      0.48      1190
# weighted avg       0.90      0.69      0.77      1190
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d06edcf1e535> in <module>
#      30   func = getattr(fn,'fill_missing_'+'_'.join(x))
#      31   title=x[0]+' '+x[1]
# ---> 32   run(title,func,30 if x[1]=='rand' else 1)
#
# <ipython-input-2-d06edcf1e535> in run(title, func, n)
#      15   for x in range(n):
#      16       df=func(config)
# ---> 17       df=fn.run_sample(df)
#      18       cm=fn.confusion_matrix(y_true=df['child_death'],y_pred=df['js_result'])
#      19       fn.plot_confusion_matrix(df,title=f'{title}{x+1}')
#
# ~/projects/config-dtree/machine-learning/testing/functions.py in run_sample(df)
#     207     js=StringIO()
#     208     df.to_csv(js,index=False)
# --> 209     df['js_result']=run_js(js.getvalue())
#     210     df['js_result']=df.js_result=='True'
#     211     df['python_result']=pd.Series(name='py_results',data=clf.predict(samples))
#
# ~/projects/config-dtree/machine-learning/testing/functions.py in run_js(data)
#     200     process = sp.Popen(['node','test.js'],stdin=sp.PIPE,stdout=sp.PIPE,stderr=sp.PIPE)
#     201     process.stdin.write(bytes(data,'utf-8'))
# --> 202     stdout, stderr = process.communicate()
#     203     return stdout.decode('utf-8').split()
#     204
#
# /usr/local/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1022
#    1023             try:
# -> 1024                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1025             except KeyboardInterrupt:
#    1026                 # https://bugs.python.org/issue25942
#
# /usr/local/lib/python3.8/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1864                             'failed to raise TimeoutExpired.')
#    1865
# -> 1866                     ready = selector.select(timeout)
#    1867                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1868
#
# /usr/local/lib/python3.8/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
# Out:
# 356
